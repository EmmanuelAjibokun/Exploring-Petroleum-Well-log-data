# %%
# %pip install petroeval
# Out:
# ...
#   Attempting uninstall: lasio
#     Found existing installation: lasio 0.31
#     Uninstalling lasio-0.31:
#       Successfully uninstalled lasio-0.31
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import petroeval as pet
from petroeval import evaluate_reservoir
from petroeval import log_plot, three_plots
from petroeval import FormationEvaluation, preprocessing
from petroeval import visualizations
from petroeval.visualizations import summary

# %%
pet
# Out:
# <module 'petroeval' from 'C:\\Users\\Manny\\anaconda3\\lib\\site-packages\\petroeval\\__init__.py'>

# %%
# Reading / Importing a single las file
las = pet.read_lasio("./well-log-data/16_8-1.las")

# %%
# Reading multiple lasio files

las1 = pet.read_lasio("./well-log-data/15_9-13.las")
las2 = pet.read_lasio("./well-log-data/25_11-5.las")

# %%
 df = las.df()

# %%
df.head()
# Out:
#            FORCE_2020_LITHOFACIES_CONFIDENCE  \
# DEPT
# 96.975197                                NaN
# 97.127197                                NaN
# 97.279197                                NaN
# 97.431197                                NaN
# 97.583197                                NaN
#
#            FORCE_2020_LITHOFACIES_LITHOLOGY  CALI  MUDWEIGHT  ROP  RDEP  RSHA  \
# DEPT
# 96.975197                               NaN   NaN        NaN  NaN   NaN   NaN
# 97.127197                               NaN   NaN        NaN  NaN   NaN   NaN
# 97.279197                               NaN   NaN        NaN  NaN   NaN   NaN
# 97.431197                               NaN   NaN        NaN  NaN   NaN   NaN
# 97.583197                               NaN   NaN        NaN  NaN   NaN   NaN
#
#            RMED  SP  DTC  NPHI      GR  RHOB  DRHO  DEPTH_MD  X_LOC  Y_LOC  \
# DEPT
# 96.975197   NaN NaN  NaN   NaN  7.3478   NaN   NaN       NaN    NaN    NaN
# ...

# %%
df.tail()
# Out:
#              FORCE_2020_LITHOFACIES_CONFIDENCE  \
# DEPT
# 2313.287197                                NaN
# 2313.439197                                NaN
# 2313.591197                                NaN
# 2313.743197                                NaN
# 2313.895197                                NaN
#
#              FORCE_2020_LITHOFACIES_LITHOLOGY  CALI  MUDWEIGHT  ROP  RDEP  \
# DEPT
# 2313.287197                               NaN   NaN        NaN  NaN   NaN
# 2313.439197                               NaN   NaN        NaN  NaN   NaN
# 2313.591197                               NaN   NaN        NaN  NaN   NaN
# 2313.743197                               NaN   NaN        NaN  NaN   NaN
# 2313.895197                               NaN   NaN        NaN  NaN   NaN
#
#              RSHA  RMED  SP  DTC  NPHI  GR  RHOB  DRHO  DEPTH_MD  X_LOC  \
# DEPT
# 2313.287197   NaN   NaN NaN  NaN   NaN NaN   NaN   NaN       NaN    NaN
# ...

# %%
df.describe()
# Out:
#        FORCE_2020_LITHOFACIES_CONFIDENCE  FORCE_2020_LITHOFACIES_LITHOLOGY  \
# count                        6700.000000                       6685.000000
# mean                            1.317015                      67808.931638
# std                             0.698308                      16871.506647
# min                             1.000000                      30000.000000
# 25%                             1.000000                      65000.000000
# 50%                             1.000000                      65000.000000
# 75%                             1.000000                      80000.000000
# max                             3.000000                      99000.000000
#
#               CALI     MUDWEIGHT           ROP          RDEP          RSHA  \
# count  6709.000000  13706.000000  14418.000000  11888.000000  11888.000000
# mean     13.874441      1.273399      7.995180      1.193640      0.994535
# ...

# %%
pet.log_plot(df, top=90, base=2300, RHOB=True)
# Out:
# NameError: Attritubute not found. Specify attribute. 'DataFrame' object has no attribute 'RT'

# %%
df = preprocessing.set_mnemonics(df,
                                 GR='GR',
                                 NPHI='NPHI',
                                 RHOB='RHOB',
                                 RT = 'RDEP')

# %%
pet.log_plot(df, top=90, base=2300, RHOB=True)
# Out:
# Depth column could not be located. local variable 'nphi_max' referenced before assignment

# %%
pet.three_plots(df, x1='GR', x2='NPHI', x3='RT', top=1250, base=2300)

# %%
pet.two_plots(df, 'GR', 'RT', top=1650, base=2300)
